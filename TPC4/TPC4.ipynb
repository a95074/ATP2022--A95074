# %%
def inserir_sala (cinema,sala):
    numsala = int(input("Introduza o número da sala"))
    filme = str(input("Introduza o nome do filme em exposição na sala"))
    nlugares = int(input("Introduza o número de lugares na sala"))
    nvendidos = []
    sala = (numsala,nlugares,nvendidos,filme)
    inserirSala(cinema,sala)
    if sala in cinema:
        print("A sala que tentou inserir já existe no sistema.")
    else:
        cinema.append (sala)
        print("A sala foi adicionada.")

def listar (cinema):
    print("Os filmes disponíveis são:" , filme)
    for sala in cinema:
        sala = numsala , nlugares , nvendidos , filme
        print(filme)

def listar_disponibilidade (cinema):
    sala = numsala , nlugares , nvendidos , filme
    print("Sala:", numsala , end="")
    print("Filme:", filme)
    print(nlugares - len(nvendidos))

def disponivel (cinema , nsala , lugar):
    res = True
    for sala in cinema:
        sala = numsala , nlugares , nvendidos , filme
        if nsala == numsala:
            if lugar in nvendidos:
                res = False
    return res
    
def venderbilhete (cinema , nsala , lugar):
    if disp(cinema,nsala,lugar) == True:
        for n in cinema:
            numsala, nlugares, nvendidos, filme = n
            if numsala == nsala:
                nvendidos.append(lugar)
                print("Lugar comprado!")
    else:
        print("O lugar que tentou comprar já não se encontra disponível")
    
    

def main ():
    print("""1 - Inserir sala;
2 - Lista filmes;
3 - Lugares disponíveis
4 - Lugar disponível em uma sala específica
5 - Vender bilhete""")

cinema = []
opção = 1

while opção != 0:
    main()
    opção = int(input("Introduza a opção que deseja: "))
    if opção == 1:
        numsala = int(input("Introduza o número da sala: "))
        filme = str(input("Introduza o fima que está em exibição na sala: "))
        nlugares = int(input("Introduza o número de lugares da sala: "))
        nvendidos = []
        sala = (numsala , filme , nlugares , nvendidos)
    elif opção == 2:
        listar(cinema)
    elif opção == 3:
        listar_disponibilidade(cinema)
    elif opção == 4:
        nsala = int(input("Introduza o número da sala que deseja informações: "))
        lugar = int(input("Introduza o lugar que deseja: "))
        disponivel(cinema , nsala , lugar)
    elif opção == 5:
        venderbilhete(cinema,nsala,lugar)
        nsala = int(input("Introduza o número da sala: "))
        lugar= int(input("Introduza o lugar: "))
    else:
        print("Introduza uma opção válida!")
